# %% [markdown]
# <a href="https://colab.research.google.com/github/Chonapatcc/Basic-programming/blob/main/Lab02Asm_6510110085.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A1. Student Information เขียนโปรแกรม รับชื่อ นามสกุล รหัสนักศึกษา (ตัวเลข 10 หลัก) คณะ แลว
# จัดเรียงเปนสตริงเดียว ระบุชั้นปดวย (คํานวณชั้นป จากปการศึกษาปจจุบัน เชน ปปจจุบันคือ 2565
# รหัสนักศึกษาขึ้นตนดวย 63 เปนนักศึกษาชั้นป 2 เปนตน) ตัวอยางการรันโปรแกรม

# %%
i=input; fname=i('Name: ');lname=i('Surname: ');code=i('Student Code: ');fac=i('Faculty: ');year=65-int(code[:2]);print(f"Student Information: {code} {fname} {lname}, {fac}, Year {year}")
# Out:
# Name: Manee
# Surname: Meeta
# Student Code: 6310110812
# Faculty: Engineering
# Student Information: 6310110812 Manee Meeta, Engineering, Year 2
